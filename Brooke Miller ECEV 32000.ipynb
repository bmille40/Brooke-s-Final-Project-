# %%
#### opening the eletrophysiology file 
#PartI Graphical Relation of Current, Voltage, and Time in Mouse Utricular HairCells  
import matplotlib.pyplot as plt #Python library for ploting graphs 
import numpy as np 
from numpy import genfromtxt
data = genfromtxt('/Users/brookemiller/Desktop/Data.csv', delimiter=',') #Import data from Data.csv parsing the data with the delimiter ','

#Time and Current Arrays for x and y value pairs in data. TimeArray corresponds to x-values and CurrentArray corresponds to y-values. Each array pair corresponds to a single plot of Time vs Current. There are 19 Current and Time arrays.    

TimeArray = []
Time2Array = []
Time3Array = []
Time4Array = []
Time5Array = []
Time6Array = []
Time7Array = []
Time8Array = []
Time9Array = []
Time10Array = []
Time11Array = []
Time12Array = []
Time13Array = []
Time14Array = []
Time15Array = []
Time16Array = []
Time17Array = []
Time18Array = []
Time19Array = []


CurrentArray = []
Current2Array = []
Current3Array = []
Current4Array = []
Current5Array = []
Current6Array = []
Current7Array = []
Current8Array = []
Current9Array = []
Current10Array = []
Current11Array = []
Current12Array = []
Current13Array = []
Current14Array = []
Current15Array = []
Current16Array = []
Current17Array = []
Current18Array = []
Current19Array = []

#For loops that are iterating through the array called data. The for loops are pulling out corresponding x and y values from data and storing in seperate arrays. X values correspond to time and y-values correspond to Current. Here listed as TimeArray or CurrentArray.    

for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 0):
            TimeArray.append(data[x][0])
        if(y == 1):
            CurrentArray.append(data[x][1]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 1):
            Time2Array.append(data[x][0])
        if(y == 2):
            Current2Array.append(data[x][2]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 2):
            Time3Array.append(data[x][0])
        if(y == 3):
            Current3Array.append(data[x][3]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 3):
            Time4Array.append(data[x][0])
        if(y == 4):
            Current4Array.append(data[x][4]) 

for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 4):
            TimeArray.append(data[x][0])
        if(y == 5):
            CurrentArray.append(data[x][5]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 5):
            Time2Array.append(data[x][0])
        if(y == 6):
            Current2Array.append(data[x][6]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 6):
            Time3Array.append(data[x][0])
        if(y == 7):
            Current3Array.append(data[x][7]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 7):
            Time4Array.append(data[x][0])
        if(y == 8):
            Current4Array.append(data[x][8]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 8):
            TimeArray.append(data[x][0])
        if(y == 9):
            CurrentArray.append(data[x][9]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 9):
            Time2Array.append(data[x][0])
        if(y == 10):
            Current2Array.append(data[x][10]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 10):
            Time3Array.append(data[x][0])
        if(y == 11):
            Current3Array.append(data[x][11]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 11):
            Time4Array.append(data[x][0])
        if(y == 12):
            Current4Array.append(data[x][12]) 
            
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 12):
            TimeArray.append(data[x][0])
        if(y == 13):
            CurrentArray.append(data[x][13]) 
count = 13
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 13):
            Time2Array.append(data[x][0])
        if(y == 14):
            Current2Array.append(data[x][14]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 15):
            Time3Array.append(data[x][0])
        if(y == 16):
            Current3Array.append(data[x][16]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 16):
            Time4Array.append(data[x][0])
        if(y == 17):
            Current4Array.append(data[x][17])
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 17):
            TimeArray.append(data[x][0])
        if(y == 18):
            CurrentArray.append(data[x][18]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 18):
            Time2Array.append(data[x][0])
        if(y == 19):
            Current2Array.append(data[x][19]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 19):
            Time3Array.append(data[x][0])
        if(y == 20):
            Current3Array.append(data[x][20]) 
            
            

            
#To Generate Time vs Current Electropysiology Graphs 
plt.figure(1) #Call to plot Time vs Current in a plot 
plt.plot(TimeArray,CurrentArray,'r',Time2Array,Current2Array,'b',Time3Array,Current3Array,'g',Time4Array,Current4Array,'m',Time5Array,Current5Array,'y',Time6Array,Current6Array,'p',Time7Array,Current7Array,'v',Time8Array,Current8Array,'r',Time9Array,Current9Array,'b',Time10Array,Current10Array,'g',Time11Array,Current11Array,'m',Time12Array,Current12Array,'y',Time13Array,Current13Array,'p',Time14Array,Current14Array,'v',Time15Array,Current15Array,'r',Time16Array,Current16Array,'b',Time17Array,Current17Array,'g',Time18Array,Current18Array,'m',Time19Array,Current19Array,'y',linewidth=2.0) # colors used red,'r', blue, 'b', magenta, 'm', yellow, 'y', pink,'p', violet,'v' and the linewidth was set at 2.0 
plt.ylabel('Current (nA)') #y-axis lable Current in nA
plt.xlabel('Time (ms)') #x-axis lable Time in msecs
plt.show(1)


 #Time and Voltage Arrays for x and y value pairs in data. TimeArray corresponds to x-values and VoltageArray corresponds to y-values. Each array pair corresponds to a single plot of Time vs Voltage. There are 19 Voltage and Time arrays.    

Time20Array = []
Time21Array = []
Time22Array = []
Time23Array = []
Time24Array = []
Time25Array = []
Time26Array = []
Time27Array = []
Time28Array = []
Time29Array = []
Time30Array = []
Time31Array = []
Time32Array = []
Time33Array = []
Time34Array = []
Time35Array = []
Time36Array = []
Time37Array = []
Time38Array = []
Time39Array = []


Voltage1Array = []
Voltage2Array = []
Voltage3Array = []
Voltage4Array = []
Voltage5Array = []
Voltage6Array = []
Voltage7Array = []
Voltage8Array = []
Voltage9Array = []
Voltage10Array = []
Voltage11Array = []
Voltage12Array = []
Voltage13Array = []
Voltage14Array = []
Voltage15Array = []
Voltage16Array = []
Voltage17Array = []
Voltage18Array = []
Voltage19Array = []

#For loops that are iterating through the array called data. The for loops are pulling out corresponding x and y values from data and storing in seperate arrays. X values correspond to time and y-values correspond to Voltage. Here listed as TimeArray or VoltageArray. 

for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 20):
            Time20Array.append(data[x][0])
        if(y == 21):
            Voltage1Array.append(data[x][21]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 21):
            Time21Array.append(data[x][0])
        if(y == 22):
            Voltage2Array.append(data[x][22]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 22):
            Time22Array.append(data[x][0])
        if(y == 23):
            Voltage3Array.append(data[x][23]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 23):
            Time23Array.append(data[x][0])
        if(y == 4):
            Voltage4Array.append(data[x][24]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 24):
            Time24Array.append(data[x][0])
        if(y == 5):
            Voltage5Array.append(data[x][25]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 25):
            Time25Array.append(data[x][0])
        if(y == 26):
            Voltage6Array.append(data[x][26]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 26):
            Time26Array.append(data[x][0])
        if(y == 27):
            Voltage7Array.append(data[x][27]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 27):
            Time27Array.append(data[x][0])
        if(y == 28):
            Voltage8Array.append(data[x][28]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 28):
            Time28Array.append(data[x][0])
        if(y == 29):
            Voltage9Array.append(data[x][29]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 29):
            Time29Array.append(data[x][0])
        if(y == 30):
            Voltage10Array.append(data[x][30]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 30):
            Time30Array.append(data[x][0])
        if(y == 11):
            Voltage11Array.append(data[x][31]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 31):
            Time31Array.append(data[x][0])
        if(y == 32):
            Voltage12Array.append(data[x][32]) 
            
count = 32
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 32):
            Time32Array.append(data[x][0])
        if(y == 33):
            Voltage13Array.append(data[x][33]) 
count = 33
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 33):
            Time33Array.append(data[x][0])
        if(y == 34):
            Voltage14Array.append(data[x][34]) 
count = 35
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 35):
            Time34Array.append(data[x][0])
        if(y == 36):
            Voltage15Array.append(data[x][36]) 
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 36):
            Time35Array.append(data[x][0])
        if(y == 37):
            Voltage16Array.append(data[x][37])
for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 37):
            Time36Array.append(data[x][0])
        if(y == 38):
            Voltage17Array.append(data[x][38]) 

for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 38):
            Time37Array.append(data[x][0])
        if(y == 39):
            Voltage18Array.append(data[x][39]) 

for x in range(len(data)):
    for y in range(len(data[x])):
        if(y == 39):
            Time38Array.append(data[x][0])
        if(y == 40):
            Voltage19Array.append(data[x][40])
            
            
#To Generate Time vs Voltage Electropysiology Graphs  
plt.figure(2) # Call to plot Time vs Voltage in a second plot
plt.plot(Time20Array,Voltage1Array,'r',Time21Array,Voltage2Array,'b',Time22Array,Voltage3Array,'g',Time23Array,Voltage4Array,'m',Time24Array,Voltage5Array,'y',Time25Array,Voltage6Array,'p',Time26Array,Voltage7Array,'v',Time27Array,Voltage8Array,'r',Time28Array,Voltage9Array,'b',Time29Array,Voltage10Array,'g',Time30Array,Voltage11Array,'m',Time31Array,Voltage12Array,'y',Time32Array,Voltage13Array,'p',Time33Array,Voltage14Array,'v',Time34Array,Voltage15Array,'r',Time35Array,Voltage16Array,'b',Time36Array,Voltage17Array,'g',Time37Array,Voltage18Array,'m',Time38Array,Voltage19Array,'y',linewidth=2.0) # colors used red,'r', blue, 'b', magenta, 'm', yellow, 'y', pink,'p', violet,'v' and the linewidth was set at 2.0 
plt.ylabel('Voltage (mV)') #y-axis lable Current in nA
plt.xlabel('Time (ms)') #x-axis lable Time in msecs
plt.show(2)
